# %% [markdown]
# # 개, 고양이 분류 - CNN v2
# - 부분 데이터: 훈련 개: 1000, 고양이: 1000; 테스트 개: 500, 고양이: 500
# - 이미지 센터링 처리

# %%
# !wget https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Out:
# --2022-05-24 06:32:52--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.202.128, 74.125.20.128, 74.125.197.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.202.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘cats_and_dogs_filtered.zip’
#
# cats_and_dogs_filte 100%[===================>]  65.43M   142MB/s    in 0.5s
#
# 2022-05-24 06:32:53 (142 MB/s) - ‘cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
# !unzip cats_and_dogs_filtered.zip > /dev/null

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 탐색

# %%
# 이미지를 축소/확대 및 센터링해서 이미지를 반환하는 함수
IMAGE_SIZE = 150

# %%
import cv2
fname = 'cats_and_dogs_filtered/train/cats/cat.475.jpg'
img = cv2.imread(fname)[:,:,::-1]
plt.imshow(img), plt.title(img.shape[:-1]);

# %%
plt.imshow(cv2.resize(img, dsize=(150,150), interpolation=cv2.INTER_AREA));

# %%
h, w, _ = img.shape
h, w
# Out:
# (287, 431)

# %%
if h > w:
    width, height = IMAGE_SIZE, (h * IMAGE_SIZE) // w
else:
    width, height = (w * IMAGE_SIZE) // h, IMAGE_SIZE

# %%
# Pillow image: new_img = np.array(img.resize((width, height)))
new_img = cv2.resize(img, dsize=(width, height), interpolation=cv2.INTER_AREA)
new_img.shape
# Out:
# (150, 225, 3)

# %%
diff = abs(width - height) // 2

# %%
if h > w:
    final_img = new_img[diff:diff+IMAGE_SIZE, :]
else:
    final_img = new_img[:, diff:diff+IMAGE_SIZE]

# %%
plt.imshow(final_img), plt.title(final_img.shape[:-1]);

# %%
from PIL import Image
def center_image(img, src_format='OpenCV', dst_format='OpenCV'):
    if src_format == 'OpenCV':
        h, w = img.shape[:-1]
    else:                       # Pillow
        h, w = np.array(img).shape[:-1]

    if h > w:
        width, height = IMAGE_SIZE, (h * IMAGE_SIZE) // w
    else:
        width, height = (w * IMAGE_SIZE) // h, IMAGE_SIZE

    interpolation = cv2.INTER_AREA if h + w > 300 else cv2.INTER_CUBIC
    new_img = cv2.resize(img, dsize=(width, height), interpolation=interpolation)

    diff = abs(width - height) // 2
    if h > w:
        final_img = new_img[diff:diff+IMAGE_SIZE, :]
    else:
        final_img = new_img[:, diff:diff+IMAGE_SIZE]

    return final_img if dst_format == 'OpenCV' else Image.fromarray(final_img)

# %%
img = cv2.imread(fname)[:,:,::-1]
plt.imshow(center_image(img));

# %% [markdown]
# - 파일에서 읽어서 센터 이미지로 변환해서 저장

# %%
CENTER_DIR = 'cats_and_dogs_centered'
train_dir = f'{CENTER_DIR}/train'
validation_dir = f'{CENTER_DIR}/validation'
train_cats_dir = f'{CENTER_DIR}/train/cats'
train_dogs_dir = f'{CENTER_DIR}/train/dogs'
validation_cats_dir = f'{CENTER_DIR}/validation/cats'
validation_dogs_dir = f'{CENTER_DIR}/validation/dogs'

# %%
import os
if not os.path.exists(CENTER_DIR):
    os.mkdir(CENTER_DIR)
for dir in [train_dir,validation_dir,train_cats_dir,train_dogs_dir,validation_cats_dir,validation_dogs_dir]:
    os.mkdir(dir)

# %%
old_train_cats_dir = 'cats_and_dogs_filtered/train/cats'
old_train_dogs_dir = 'cats_and_dogs_filtered/train/dogs'
old_validation_cats_dir = 'cats_and_dogs_filtered/validation/cats'
old_validation_dogs_dir = 'cats_and_dogs_filtered/validation/dogs'

# %%
# cats_and_dogs_filtered -> image 축소/확대후 centering -> cats_and_dogs_centered
from glob import glob

for src_dir in [old_train_cats_dir,old_train_dogs_dir,old_validation_cats_dir,old_validation_dogs_dir]:
    dst_dir = src_dir.replace('filtered', 'centered')
    for fname in glob(f'{src_dir}/*.jpg'):
        dst_fname = fname.split('/')[-1]
        src_img = cv2.imread(fname)[:,:,::-1]
        dst_img = center_image(src_img, src_format='OpenCV', dst_format='Pillow')
        dst_img.save(f'{dst_dir}/{dst_fname}')

# %%
# 파일 이름
train_cats_fnames = os.listdir(train_cats_dir)
train_dogs_fnames = os.listdir(train_dogs_dir)

# %%
plt.figure(figsize=(12,6))
for i in range(4):
    plt.subplot(2, 4, i+1)
    cat = cv2.imread(os.path.join(train_cats_dir, train_cats_fnames[i]))[:,:,::-1]
    plt.imshow(cat), plt.axis('off'), plt.title(cat.shape[:-1])
    plt.subplot(2, 4, i+5)
    dog = cv2.imread(os.path.join(train_dogs_dir, train_dogs_fnames[i]))[:,:,::-1]
    plt.imshow(dog), plt.axis('off'), plt.title(dog.shape[:-1])
plt.show()

# %% [markdown]
# - 모델 구성 및 학습

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([ 
    Conv2D(16, (3,3), input_shape=(150,150,3), activation='relu'),
    MaxPooling2D(),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(
    optimizer=RMSprop(learning_rate=0.001, decay=1e-8),
    loss='binary_crossentropy', metrics=['accuracy']
)

# %%
model_path = 'best-cats-and-dogs-v2.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=10)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
test_generator = test_datagen.flow_from_directory(
    validation_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
hist = model.fit(
    train_generator, 
    validation_data=test_generator,
    epochs=100, steps_per_epoch=100,
    validation_steps=50, callbacks=[mc, es]
)
# Out:
# Epoch 1/100
# 100/100 [==============================] - ETA: 0s - loss: 0.7611 - accuracy: 0.5680
# Epoch 1: val_loss improved from inf to 0.63903, saving model to best-cats-and-dogs-v2.h5
# 100/100 [==============================] - 17s 39ms/step - loss: 0.7611 - accuracy: 0.5680 - val_loss: 0.6390 - val_accuracy: 0.6400
# Epoch 2/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6471 - accuracy: 0.6565
# Epoch 2: val_loss improved from 0.63903 to 0.62700, saving model to best-cats-and-dogs-v2.h5
# 100/100 [==============================] - 4s 35ms/step - loss: 0.6471 - accuracy: 0.6565 - val_loss: 0.6270 - val_accuracy: 0.6590
# Epoch 3/100
#  98/100 [============================>.] - ETA: 0s - loss: 0.5763 - accuracy: 0.6959
# Epoch 3: val_loss improved from 0.62700 to 0.59799, saving model to best-cats-and-dogs-v2.h5
# 100/100 [==============================] - 4s 37ms/step - loss: 0.5773 - accuracy: 0.6945 - val_loss: 0.5980 - val_accuracy: 0.6820
# Epoch 4/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5052 - accuracy: 0.7460
# Epoch 4: val_loss did not improve from 0.59799
# 100/100 [==============================] - 3s 33ms/step - loss: 0.5052 - accuracy: 0.7460 - val_loss: 0.6169 - val_accuracy: 0.6860
# Epoch 5/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.4252 - accuracy: 0.7949
# Epoch 5: val_loss did not improve from 0.59799
# 100/100 [==============================] - 3s 32ms/step - loss: 0.4255 - accuracy: 0.7950 - val_loss: 0.6658 - val_accuracy: 0.6910
# Epoch 6/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3628 - accuracy: 0.8359
# Epoch 6: val_loss did not improve from 0.59799
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3624 - accuracy: 0.8370 - val_loss: 0.8154 - val_accuracy: 0.6880
# Epoch 7/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2560 - accuracy: 0.8904
# Epoch 7: val_loss did not improve from 0.59799
# 100/100 [==============================] - 3s 32ms/step - loss: 0.2555 - accuracy: 0.8910 - val_loss: 0.8858 - val_accuracy: 0.6620
# Epoch 8/100
#  98/100 [============================>.] - ETA: 0s - loss: 0.1972 - accuracy: 0.9250
# Epoch 8: val_loss did not improve from 0.59799
# 100/100 [==============================] - 3s 35ms/step - loss: 0.1964 - accuracy: 0.9250 - val_loss: 1.0748 - val_accuracy: 0.6760
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1355 - accuracy: 0.9490
# Epoch 9: val_loss did not improve from 0.59799
# 100/100 [==============================] - 4s 36ms/step - loss: 0.1355 - accuracy: 0.9490 - val_loss: 1.2820 - val_accuracy: 0.6720
# Epoch 10/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.0871 - accuracy: 0.9768
# Epoch 10: val_loss did not improve from 0.59799
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0885 - accuracy: 0.9760 - val_loss: 1.8232 - val_accuracy: 0.6460
# Epoch 11/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9735
# Epoch 11: val_loss did not improve from 0.59799
# 100/100 [==============================] - 3s 32ms/step - loss: 0.1034 - accuracy: 0.9735 - val_loss: 1.7440 - val_accuracy: 0.6800
# Epoch 12/100
#  98/100 [============================>.] - ETA: 0s - loss: 0.0449 - accuracy: 0.9837
# Epoch 12: val_loss did not improve from 0.59799
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0443 - accuracy: 0.9840 - val_loss: 2.0923 - val_accuracy: 0.6670
# Epoch 13/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9825
# Epoch 13: val_loss did not improve from 0.59799
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0487 - accuracy: 0.9825 - val_loss: 1.8883 - val_accuracy: 0.6820
