# %% [markdown]
# # Cifar-10 이미지 분류 - v1

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1), (10000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
plt.figure(figsize=(8,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X_data: scaling
X_train = X_train/255.
X_test = X_test/255.

# %%
# y_data: one hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([ 
    Conv2D(32, (3,3), input_shape=X_train.shape[1:], padding='same', activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy', metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v1.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=32, callbacks=[mc, es]
)
# Out:
# Epoch 1/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.8306 - accuracy: 0.3275
# Epoch 1: val_loss improved from inf to 1.57581, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 19s 6ms/step - loss: 1.8306 - accuracy: 0.3275 - val_loss: 1.5758 - val_accuracy: 0.4243
# Epoch 2/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.5249 - accuracy: 0.4416
# Epoch 2: val_loss improved from 1.57581 to 1.38373, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 1.5247 - accuracy: 0.4421 - val_loss: 1.3837 - val_accuracy: 0.5032
# Epoch 3/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.3992 - accuracy: 0.4930
# Epoch 3: val_loss improved from 1.38373 to 1.27580, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.3992 - accuracy: 0.4930 - val_loss: 1.2758 - val_accuracy: 0.5519
# Epoch 4/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.3021 - accuracy: 0.5330
# Epoch 4: val_loss improved from 1.27580 to 1.24778, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.3023 - accuracy: 0.5330 - val_loss: 1.2478 - val_accuracy: 0.5518
# Epoch 5/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.2224 - accuracy: 0.5651
# Epoch 5: val_loss improved from 1.24778 to 1.20205, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 1.2224 - accuracy: 0.5651 - val_loss: 1.2021 - val_accuracy: 0.5810
# Epoch 6/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.1600 - accuracy: 0.5894
# Epoch 6: val_loss improved from 1.20205 to 1.06386, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.1597 - accuracy: 0.5896 - val_loss: 1.0639 - val_accuracy: 0.6305
# Epoch 7/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1041 - accuracy: 0.6141
# Epoch 7: val_loss did not improve from 1.06386
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.1040 - accuracy: 0.6141 - val_loss: 1.0667 - val_accuracy: 0.6225
# Epoch 8/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.0599 - accuracy: 0.6291
# Epoch 8: val_loss improved from 1.06386 to 0.99992, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.0592 - accuracy: 0.6293 - val_loss: 0.9999 - val_accuracy: 0.6482
# Epoch 9/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.0169 - accuracy: 0.6449
# Epoch 9: val_loss improved from 0.99992 to 0.96774, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.0170 - accuracy: 0.6449 - val_loss: 0.9677 - val_accuracy: 0.6592
# Epoch 10/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9822 - accuracy: 0.6557
# Epoch 10: val_loss did not improve from 0.96774
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.9822 - accuracy: 0.6557 - val_loss: 0.9719 - val_accuracy: 0.6556
# Epoch 11/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.9521 - accuracy: 0.6685
# Epoch 11: val_loss improved from 0.96774 to 0.88643, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9525 - accuracy: 0.6684 - val_loss: 0.8864 - val_accuracy: 0.6879
# Epoch 12/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.9246 - accuracy: 0.6767
# Epoch 12: val_loss improved from 0.88643 to 0.87435, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9247 - accuracy: 0.6768 - val_loss: 0.8743 - val_accuracy: 0.6937
# Epoch 13/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9007 - accuracy: 0.6860
# Epoch 13: val_loss did not improve from 0.87435
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.9007 - accuracy: 0.6860 - val_loss: 0.8784 - val_accuracy: 0.6892
# Epoch 14/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.8780 - accuracy: 0.6945
# Epoch 14: val_loss improved from 0.87435 to 0.83373, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.8779 - accuracy: 0.6944 - val_loss: 0.8337 - val_accuracy: 0.7071
# Epoch 15/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8536 - accuracy: 0.7071
# Epoch 15: val_loss did not improve from 0.83373
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.8539 - accuracy: 0.7071 - val_loss: 0.8348 - val_accuracy: 0.7056
# Epoch 16/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.8386 - accuracy: 0.7088
# Epoch 16: val_loss improved from 0.83373 to 0.81492, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.8395 - accuracy: 0.7085 - val_loss: 0.8149 - val_accuracy: 0.7168
# Epoch 17/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.8236 - accuracy: 0.7148
# Epoch 17: val_loss improved from 0.81492 to 0.79083, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.8230 - accuracy: 0.7152 - val_loss: 0.7908 - val_accuracy: 0.7253
# Epoch 18/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8042 - accuracy: 0.7223
# Epoch 18: val_loss improved from 0.79083 to 0.78084, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.8039 - accuracy: 0.7224 - val_loss: 0.7808 - val_accuracy: 0.7299
# Epoch 19/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.7932 - accuracy: 0.7249
# Epoch 19: val_loss did not improve from 0.78084
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7929 - accuracy: 0.7250 - val_loss: 0.7823 - val_accuracy: 0.7281
# Epoch 20/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.7825 - accuracy: 0.7323
# Epoch 20: val_loss improved from 0.78084 to 0.76433, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7825 - accuracy: 0.7323 - val_loss: 0.7643 - val_accuracy: 0.7356
# Epoch 21/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.7689 - accuracy: 0.7333
# Epoch 21: val_loss did not improve from 0.76433
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7683 - accuracy: 0.7335 - val_loss: 0.7702 - val_accuracy: 0.7324
# Epoch 22/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7588 - accuracy: 0.7375
# Epoch 22: val_loss improved from 0.76433 to 0.75611, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7585 - accuracy: 0.7376 - val_loss: 0.7561 - val_accuracy: 0.7437
# Epoch 23/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7501 - accuracy: 0.7426
# Epoch 23: val_loss improved from 0.75611 to 0.73677, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7505 - accuracy: 0.7424 - val_loss: 0.7368 - val_accuracy: 0.7469
# Epoch 24/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7348 - accuracy: 0.7468
# Epoch 24: val_loss did not improve from 0.73677
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7348 - accuracy: 0.7468 - val_loss: 0.7369 - val_accuracy: 0.7480
# Epoch 25/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7347 - accuracy: 0.7480
# Epoch 25: val_loss improved from 0.73677 to 0.72524, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7343 - accuracy: 0.7482 - val_loss: 0.7252 - val_accuracy: 0.7537
# Epoch 26/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7223 - accuracy: 0.7538
# Epoch 26: val_loss improved from 0.72524 to 0.71437, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.7223 - accuracy: 0.7538 - val_loss: 0.7144 - val_accuracy: 0.7574
# Epoch 27/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7194 - accuracy: 0.7551
# Epoch 27: val_loss improved from 0.71437 to 0.71217, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7195 - accuracy: 0.7550 - val_loss: 0.7122 - val_accuracy: 0.7578
# Epoch 28/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7126 - accuracy: 0.7570
# Epoch 28: val_loss improved from 0.71217 to 0.71148, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7135 - accuracy: 0.7565 - val_loss: 0.7115 - val_accuracy: 0.7524
# Epoch 29/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.7076 - accuracy: 0.7580
# Epoch 29: val_loss improved from 0.71148 to 0.69698, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7078 - accuracy: 0.7582 - val_loss: 0.6970 - val_accuracy: 0.7628
# Epoch 30/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.7038 - accuracy: 0.7620
# Epoch 30: val_loss improved from 0.69698 to 0.69559, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7039 - accuracy: 0.7620 - val_loss: 0.6956 - val_accuracy: 0.7632
# Epoch 31/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6980 - accuracy: 0.7613
# Epoch 31: val_loss did not improve from 0.69559
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6980 - accuracy: 0.7613 - val_loss: 0.7036 - val_accuracy: 0.7637
# Epoch 32/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6959 - accuracy: 0.7624
# Epoch 32: val_loss did not improve from 0.69559
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6964 - accuracy: 0.7623 - val_loss: 0.7400 - val_accuracy: 0.7481
# Epoch 33/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6851 - accuracy: 0.7651
# Epoch 33: val_loss did not improve from 0.69559
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6849 - accuracy: 0.7653 - val_loss: 0.6978 - val_accuracy: 0.7616
# Epoch 34/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6795 - accuracy: 0.7686
# Epoch 34: val_loss did not improve from 0.69559
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6795 - accuracy: 0.7686 - val_loss: 0.6973 - val_accuracy: 0.7628
# Epoch 35/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6786 - accuracy: 0.7689
# Epoch 35: val_loss did not improve from 0.69559
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6786 - accuracy: 0.7689 - val_loss: 0.7269 - val_accuracy: 0.7536
# Epoch 36/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6813 - accuracy: 0.7685
# Epoch 36: val_loss did not improve from 0.69559
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6812 - accuracy: 0.7685 - val_loss: 0.7065 - val_accuracy: 0.7579
# Epoch 37/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6774 - accuracy: 0.7690
# Epoch 37: val_loss improved from 0.69559 to 0.68361, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6774 - accuracy: 0.7690 - val_loss: 0.6836 - val_accuracy: 0.7652
# Epoch 38/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.7720
# Epoch 38: val_loss did not improve from 0.68361
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6712 - accuracy: 0.7721 - val_loss: 0.6838 - val_accuracy: 0.7673
# Epoch 39/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6672 - accuracy: 0.7732
# Epoch 39: val_loss did not improve from 0.68361
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6674 - accuracy: 0.7732 - val_loss: 0.6895 - val_accuracy: 0.7642
# Epoch 40/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6669 - accuracy: 0.7748
# Epoch 40: val_loss improved from 0.68361 to 0.67310, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6662 - accuracy: 0.7750 - val_loss: 0.6731 - val_accuracy: 0.7693
# Epoch 41/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6608 - accuracy: 0.7766
# Epoch 41: val_loss did not improve from 0.67310
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6609 - accuracy: 0.7767 - val_loss: 0.6888 - val_accuracy: 0.7673
# Epoch 42/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6611 - accuracy: 0.7770
# Epoch 42: val_loss did not improve from 0.67310
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.6611 - accuracy: 0.7770 - val_loss: 0.6816 - val_accuracy: 0.7698
# Epoch 43/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6489 - accuracy: 0.7830
# Epoch 43: val_loss improved from 0.67310 to 0.67121, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6495 - accuracy: 0.7828 - val_loss: 0.6712 - val_accuracy: 0.7738
# Epoch 44/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6536 - accuracy: 0.7795
# Epoch 44: val_loss did not improve from 0.67121
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6545 - accuracy: 0.7793 - val_loss: 0.6816 - val_accuracy: 0.7709
# Epoch 45/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6529 - accuracy: 0.7803
# Epoch 45: val_loss did not improve from 0.67121
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6536 - accuracy: 0.7800 - val_loss: 0.6955 - val_accuracy: 0.7751
# Epoch 46/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6476 - accuracy: 0.7811
# Epoch 46: val_loss did not improve from 0.67121
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6480 - accuracy: 0.7809 - val_loss: 0.6806 - val_accuracy: 0.7711
# Epoch 47/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.6472 - accuracy: 0.7829
# Epoch 47: val_loss improved from 0.67121 to 0.66165, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6473 - accuracy: 0.7828 - val_loss: 0.6616 - val_accuracy: 0.7768
# Epoch 48/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6374 - accuracy: 0.7844
# Epoch 48: val_loss did not improve from 0.66165
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6376 - accuracy: 0.7844 - val_loss: 0.6629 - val_accuracy: 0.7750
# Epoch 49/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6414 - accuracy: 0.7836
# Epoch 49: val_loss did not improve from 0.66165
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6411 - accuracy: 0.7836 - val_loss: 0.6719 - val_accuracy: 0.7747
# Epoch 50/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6370 - accuracy: 0.7849
# Epoch 50: val_loss did not improve from 0.66165
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6368 - accuracy: 0.7851 - val_loss: 0.6700 - val_accuracy: 0.7710
# Epoch 51/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6332 - accuracy: 0.7861
# Epoch 51: val_loss improved from 0.66165 to 0.65453, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6332 - accuracy: 0.7861 - val_loss: 0.6545 - val_accuracy: 0.7777
# Epoch 52/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6386 - accuracy: 0.7851
# Epoch 52: val_loss did not improve from 0.65453
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6390 - accuracy: 0.7850 - val_loss: 0.6603 - val_accuracy: 0.7750
# Epoch 53/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6279 - accuracy: 0.7870
# Epoch 53: val_loss did not improve from 0.65453
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6278 - accuracy: 0.7869 - val_loss: 0.6723 - val_accuracy: 0.7739
# Epoch 54/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.6353 - accuracy: 0.7860
# Epoch 54: val_loss did not improve from 0.65453
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6349 - accuracy: 0.7862 - val_loss: 0.6652 - val_accuracy: 0.7797
# Epoch 55/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6291 - accuracy: 0.7874
# Epoch 55: val_loss did not improve from 0.65453
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6291 - accuracy: 0.7874 - val_loss: 0.6856 - val_accuracy: 0.7784
# Epoch 56/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6273 - accuracy: 0.7884
# Epoch 56: val_loss did not improve from 0.65453
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6285 - accuracy: 0.7880 - val_loss: 0.6647 - val_accuracy: 0.7770
# Epoch 57/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6282 - accuracy: 0.7887
# Epoch 57: val_loss did not improve from 0.65453
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6283 - accuracy: 0.7887 - val_loss: 0.6611 - val_accuracy: 0.7799
# Epoch 58/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6276 - accuracy: 0.7905
# Epoch 58: val_loss did not improve from 0.65453
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6275 - accuracy: 0.7905 - val_loss: 0.7197 - val_accuracy: 0.7655
# Epoch 59/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6195 - accuracy: 0.7928
# Epoch 59: val_loss did not improve from 0.65453
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6194 - accuracy: 0.7928 - val_loss: 0.6974 - val_accuracy: 0.7741
# Epoch 60/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6182 - accuracy: 0.7920
# Epoch 60: val_loss did not improve from 0.65453
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6182 - accuracy: 0.7920 - val_loss: 0.6755 - val_accuracy: 0.7776
# Epoch 61/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6213 - accuracy: 0.7925
# Epoch 61: val_loss improved from 0.65453 to 0.65400, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6214 - accuracy: 0.7923 - val_loss: 0.6540 - val_accuracy: 0.7821
# Epoch 62/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6120 - accuracy: 0.7944
# Epoch 62: val_loss did not improve from 0.65400
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6123 - accuracy: 0.7943 - val_loss: 0.6854 - val_accuracy: 0.7729
# Epoch 63/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6186 - accuracy: 0.7915
# Epoch 63: val_loss did not improve from 0.65400
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6192 - accuracy: 0.7914 - val_loss: 0.6780 - val_accuracy: 0.7784
# Epoch 64/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6149 - accuracy: 0.7928
# Epoch 64: val_loss improved from 0.65400 to 0.64614, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6148 - accuracy: 0.7929 - val_loss: 0.6461 - val_accuracy: 0.7840
# Epoch 65/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6150 - accuracy: 0.7934
# Epoch 65: val_loss did not improve from 0.64614
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6147 - accuracy: 0.7933 - val_loss: 0.6796 - val_accuracy: 0.7753
# Epoch 66/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6103 - accuracy: 0.7969
# Epoch 66: val_loss did not improve from 0.64614
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6109 - accuracy: 0.7967 - val_loss: 0.6494 - val_accuracy: 0.7852
# Epoch 67/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6057 - accuracy: 0.7956
# Epoch 67: val_loss did not improve from 0.64614
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6052 - accuracy: 0.7958 - val_loss: 0.6655 - val_accuracy: 0.7865
# Epoch 68/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6102 - accuracy: 0.7943
# Epoch 68: val_loss did not improve from 0.64614
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6101 - accuracy: 0.7942 - val_loss: 0.6524 - val_accuracy: 0.7838
# Epoch 69/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6072 - accuracy: 0.7962
# Epoch 69: val_loss did not improve from 0.64614
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6061 - accuracy: 0.7965 - val_loss: 0.6569 - val_accuracy: 0.7837
# Epoch 70/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6089 - accuracy: 0.7978
# Epoch 70: val_loss did not improve from 0.64614
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6088 - accuracy: 0.7978 - val_loss: 0.6590 - val_accuracy: 0.7845
# Epoch 71/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6044 - accuracy: 0.7989
# Epoch 71: val_loss did not improve from 0.64614
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6045 - accuracy: 0.7989 - val_loss: 0.6691 - val_accuracy: 0.7886
# Epoch 72/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6095 - accuracy: 0.7964
# Epoch 72: val_loss did not improve from 0.64614
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6097 - accuracy: 0.7964 - val_loss: 0.6667 - val_accuracy: 0.7800
# Epoch 73/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6023 - accuracy: 0.7978
# Epoch 73: val_loss did not improve from 0.64614
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6028 - accuracy: 0.7978 - val_loss: 0.6810 - val_accuracy: 0.7806
# Epoch 74/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.5992 - accuracy: 0.8008
# Epoch 74: val_loss did not improve from 0.64614
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.5992 - accuracy: 0.8008 - val_loss: 0.6762 - val_accuracy: 0.7782

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6617 - accuracy: 0.7801
# [0.6616812348365784, 0.7800999879837036]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid(), plt.ylim(0,1.2),
plt.xlabel('Epoch')
plt.title('Cifar-10 CNN model v1')
plt.show()
